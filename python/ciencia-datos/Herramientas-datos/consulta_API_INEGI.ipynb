# %% [markdown]
# # Consulta a API del INEGI
#
# https://www.inegi.org.mx/servicios/api_indicadores.html

# %%
import requests
import pandas as pd
import sqlite3
import json

# URL de la API
#url = "https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/3104003001,6200205262,6200240404,6200240501,6207129646/es/99/true/BISE/2.0/d312de10-427b-d618-3b58-f77e37afd922?type=json"
url = "https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/3104003001/es/070000010001/true/BISE/2.0/d312de10-427b-d618-3b58-f77e37afd922?type=json"


# Realizar la solicitud HTTP
response = requests.get(url)
data = response.json()


# Verificar salida de datos

print(response.text)  # Imprime la respuesta completa de la solicitud


print(json.dumps(data, indent=4))  # Imprime la respuesta JSON con formato



# Convertir los datos en un DataFrame de pandas
series = data["Series"]
df_list = []
for item in series:
    indicator_data = item["OBSERVATIONS"][0]
    df_list.append(indicator_data)
df = pd.DataFrame(df_list)

# Guardar los datos en un archivo CSV
csv_filename = "datos_censo2.csv"
df.to_csv(csv_filename, index=False)

# Guardar los datos en una base de datos SQLite
db_filename = "datos_censo2.db"
conn = sqlite3.connect(db_filename)
df.to_sql("datos", conn, index=False, if_exists="replace")
conn.close()

print("Datos guardados exitosamente en", csv_filename, "y", db_filename)
# Out:
# {"Header":{"Name":"Datos compactos BISE","Email":"atencion.usuarios@inegi.org.mx"},"Series":[{"INDICADOR":"3104003001","FREQ":"6","TOPIC":"130","UNIT":"3","UNIT_MULT":"","NOTE":"186","SOURCE":"3001","LASTUPDATE":"08/12/2022","STATUS":"3","OBSERVATIONS":[{"TIME_PERIOD":"2020","OBS_VALUE":"4.91475734535307000000","OBS_EXCEPTION":null,"OBS_STATUS":"3","OBS_SOURCE":"","OBS_NOTE":"","COBER_GEO":"070000010001"}]}]}
# {
#     "Header": {
#         "Name": "Datos compactos BISE",
#         "Email": "atencion.usuarios@inegi.org.mx"
#     },
#     "Series": [
#         {
#             "INDICADOR": "3104003001",
#             "FREQ": "6",
#             "TOPIC": "130",
#             "UNIT": "3",
#             "UNIT_MULT": "",
#             "NOTE": "186",
#             "SOURCE": "3001",
#             "LASTUPDATE": "08/12/2022",
#             "STATUS": "3",
#             "OBSERVATIONS": [
#                 {
#                     "TIME_PERIOD": "2020",
#                     "OBS_VALUE": "4.91475734535307000000",
#                     "OBS_EXCEPTION": null,
#                     "OBS_STATUS": "3",
#                     "OBS_SOURCE": "",
#                     "OBS_NOTE": "",
#                     "COBER_GEO": "070000010001"
#                 }
#             ]
#         }
#     ]
# }
# Datos guardados exitosamente en datos_censo2.csv y datos_censo2.db

# %% [markdown]
# # Segunda prueba
# Esta segunda prueba ya incluye un análisis de los indicadores y metadatos en la documentación del INEGI:
#
# [https://www.inegi.org.mx/servicios/api_indicadores.html]
#
# También toma un archivo .csv con los códigos de municipios

# %%
import requests
import pandas as pd
import json

# Tu API key
api_key = "d312de10-427b-d618-3b58-f77e37afd922"

# URL base de la API
base_url = "https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml"

# Cargar los códigos de municipios desde un archivo CSV
municipios_df = pd.read_csv("municipios.csv")  # Cambia "municipios.csv" al nombre de tu archivo CSV

# Lista de indicadores (reemplaza con los valores necesarios)
indicadores = ["3104003001", "6200205277", "6200205262", "6200240404", "6200240501", "6207129646"]

# Inicializar una lista para almacenar los datos
all_data = []


# Iterar a través de los indicadores y municipios
for indicador in indicadores:
    for _, row in municipios_df.iterrows():
        municipio = row["NombreMunicipio"]  # Asegúrate de que la columna tenga el nombre correcto
        codigo_municipio = row["CodigoMunicipio"]  # Asegúrate de que la columna tenga el nombre correcto
        
        url = f"{base_url}/INDICATOR/{indicador}/COBER_GEO/{codigo_municipio}/es/BISE/2.0/{api_key}?type=json"
        
        print(f"Solicitando datos para Indicador: {indicador}, Municipio: {municipio}")
        
        # Realizar la solicitud HTTP
        response = requests.get(url)
        
        print(f"Respuesta recibida. Código de estado: {response.status_code}")
        
        # Verificar si la solicitud fue exitosa y si se pudo decodificar un JSON válido
        if response.status_code == 200:
            try:
                data = response.json()
                if isinstance(data["Series"], list):  # Verificar si "Series" es una lista
                    all_data.extend(data["Series"])
                else:
                    print(f"La respuesta no contiene una lista en la clave 'Series'. Indicador: {indicador}, Municipio: {municipio}")
            except json.JSONDecodeError as e:
                print(f"Error al decodificar JSON. Indicador: {indicador}, Municipio: {municipio}. Detalles: {e}")
        else:
            print(f"Error en la solicitud para el indicador {indicador} y el municipio {municipio}. Código de estado: {response.status_code}")

# ... (código posterior) ...



# Crear un DataFrame con todos los datos
df = pd.json_normalize(all_data)

# Guardar los datos en un archivo CSV
csv_filename = "datos_censo_migracion_2020.csv"
df.to_csv(csv_filename, index=False)

print("Datos guardados exitosamente en", csv_filename)
# Out:
# Solicitando datos para Indicador: 3104003001, Municipio: Estados Unidos Mexicanos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Estados Unidos Mexicanos
# Solicitando datos para Indicador: 3104003001, Municipio: Aguascalientes
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Aguascalientes
# Solicitando datos para Indicador: 3104003001, Municipio: Aguascalientes
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Aguascalientes
# Solicitando datos para Indicador: 3104003001, Municipio: Asientos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Asientos
# Solicitando datos para Indicador: 3104003001, Municipio: Calvillo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Calvillo
# Solicitando datos para Indicador: 3104003001, Municipio: Cosío
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Cosío
# Solicitando datos para Indicador: 3104003001, Municipio: Jesús María
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Jesús María
# Solicitando datos para Indicador: 3104003001, Municipio: Pabellón de Arteaga
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pabellón de Arteaga
# Solicitando datos para Indicador: 3104003001, Municipio: Rincón de Romos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Rincón de Romos
# Solicitando datos para Indicador: 3104003001, Municipio: San José de Gracia
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San José de Gracia
# Solicitando datos para Indicador: 3104003001, Municipio: Tepezalá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tepezalá
# Solicitando datos para Indicador: 3104003001, Municipio: El Llano
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: El Llano
# Solicitando datos para Indicador: 3104003001, Municipio: San Francisco de los Romo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Francisco de los Romo
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Otros municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Resto de municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Resto de municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Baja California
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Baja California
# Solicitando datos para Indicador: 3104003001, Municipio: Ensenada
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ensenada
# Solicitando datos para Indicador: 3104003001, Municipio: Mexicali
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mexicali
# Solicitando datos para Indicador: 3104003001, Municipio: Tecate
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tecate
# Solicitando datos para Indicador: 3104003001, Municipio: Tijuana
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tijuana
# Solicitando datos para Indicador: 3104003001, Municipio: Playas de Rosarito
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Playas de Rosarito
# Solicitando datos para Indicador: 3104003001, Municipio: San Quintín
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Quintín
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Baja California Sur
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Baja California Sur
# Solicitando datos para Indicador: 3104003001, Municipio: Comondú
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Comondú
# Solicitando datos para Indicador: 3104003001, Municipio: Mulegé
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mulegé
# Solicitando datos para Indicador: 3104003001, Municipio: La Paz
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Paz
# Solicitando datos para Indicador: 3104003001, Municipio: Los Cabos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Los Cabos
# Solicitando datos para Indicador: 3104003001, Municipio: Loreto
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Loreto
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Campeche
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Campeche
# Solicitando datos para Indicador: 3104003001, Municipio: Calkiní
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Calkiní
# Solicitando datos para Indicador: 3104003001, Municipio: Campeche
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Campeche
# Solicitando datos para Indicador: 3104003001, Municipio: Carmen
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Carmen
# Solicitando datos para Indicador: 3104003001, Municipio: Champotón
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Champotón
# Solicitando datos para Indicador: 3104003001, Municipio: Hecelchakán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Hecelchakán
# Solicitando datos para Indicador: 3104003001, Municipio: Hopelchén
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Hopelchén
# Solicitando datos para Indicador: 3104003001, Municipio: Palizada
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Palizada
# Solicitando datos para Indicador: 3104003001, Municipio: Tenabo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tenabo
# Solicitando datos para Indicador: 3104003001, Municipio: Escárcega
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Escárcega
# Solicitando datos para Indicador: 3104003001, Municipio: Calakmul
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Calakmul
# Solicitando datos para Indicador: 3104003001, Municipio: Candelaria
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Candelaria
# Solicitando datos para Indicador: 3104003001, Municipio: Seybaplaya
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Seybaplaya
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Coahuila de Zaragoza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Coahuila de Zaragoza
# Solicitando datos para Indicador: 3104003001, Municipio: Abasolo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Abasolo
# Solicitando datos para Indicador: 3104003001, Municipio: Acuña
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Acuña
# Solicitando datos para Indicador: 3104003001, Municipio: Allende
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Allende
# Solicitando datos para Indicador: 3104003001, Municipio: Arteaga
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Arteaga
# Solicitando datos para Indicador: 3104003001, Municipio: Candela
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Candela
# Solicitando datos para Indicador: 3104003001, Municipio: Castaños
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Castaños
# Solicitando datos para Indicador: 3104003001, Municipio: Cuatro Ciénegas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Cuatro Ciénegas
# Solicitando datos para Indicador: 3104003001, Municipio: Escobedo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Escobedo
# Solicitando datos para Indicador: 3104003001, Municipio: Francisco I. Madero
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Francisco I. Madero
# Solicitando datos para Indicador: 3104003001, Municipio: Frontera
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Frontera
# Solicitando datos para Indicador: 3104003001, Municipio: General Cepeda
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: General Cepeda
# Solicitando datos para Indicador: 3104003001, Municipio: Guerrero
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Guerrero
# Solicitando datos para Indicador: 3104003001, Municipio: Hidalgo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Hidalgo
# Solicitando datos para Indicador: 3104003001, Municipio: Jiménez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Jiménez
# Solicitando datos para Indicador: 3104003001, Municipio: Juárez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Juárez
# Solicitando datos para Indicador: 3104003001, Municipio: Lamadrid
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Lamadrid
# Solicitando datos para Indicador: 3104003001, Municipio: Matamoros
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Matamoros
# Solicitando datos para Indicador: 3104003001, Municipio: Monclova
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Monclova
# Solicitando datos para Indicador: 3104003001, Municipio: Morelos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Morelos
# Solicitando datos para Indicador: 3104003001, Municipio: Múzquiz
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Múzquiz
# Solicitando datos para Indicador: 3104003001, Municipio: Nadadores
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Nadadores
# Solicitando datos para Indicador: 3104003001, Municipio: Nava
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Nava
# Solicitando datos para Indicador: 3104003001, Municipio: Ocampo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ocampo
# Solicitando datos para Indicador: 3104003001, Municipio: Parras
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Parras
# Solicitando datos para Indicador: 3104003001, Municipio: Piedras Negras
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Piedras Negras
# Solicitando datos para Indicador: 3104003001, Municipio: Progreso
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Progreso
# Solicitando datos para Indicador: 3104003001, Municipio: Ramos Arizpe
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ramos Arizpe
# Solicitando datos para Indicador: 3104003001, Municipio: Sabinas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sabinas
# Solicitando datos para Indicador: 3104003001, Municipio: Sacramento
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sacramento
# Solicitando datos para Indicador: 3104003001, Municipio: Saltillo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Saltillo
# Solicitando datos para Indicador: 3104003001, Municipio: San Buenaventura
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Buenaventura
# Solicitando datos para Indicador: 3104003001, Municipio: San Juan de Sabinas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Juan de Sabinas
# Solicitando datos para Indicador: 3104003001, Municipio: San Pedro
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Pedro
# Solicitando datos para Indicador: 3104003001, Municipio: Sierra Mojada
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sierra Mojada
# Solicitando datos para Indicador: 3104003001, Municipio: Torreón
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Torreón
# Solicitando datos para Indicador: 3104003001, Municipio: Viesca
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Viesca
# Solicitando datos para Indicador: 3104003001, Municipio: Villa Unión
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Villa Unión
# Solicitando datos para Indicador: 3104003001, Municipio: Zaragoza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Zaragoza
# Solicitando datos para Indicador: 3104003001, Municipio: 901-Municipios metropolitanos Monclova y Frontera
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: 901-Municipios metropolitanos Monclova y Frontera
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Otros municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Resto de municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Resto de municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Colima
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Colima
# Solicitando datos para Indicador: 3104003001, Municipio: Armería
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Armería
# Solicitando datos para Indicador: 3104003001, Municipio: Colima
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Colima
# Solicitando datos para Indicador: 3104003001, Municipio: Comala
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Comala
# Solicitando datos para Indicador: 3104003001, Municipio: Coquimatlán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Coquimatlán
# Solicitando datos para Indicador: 3104003001, Municipio: Cuauhtémoc
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Cuauhtémoc
# Solicitando datos para Indicador: 3104003001, Municipio: Ixtlahuacán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ixtlahuacán
# Solicitando datos para Indicador: 3104003001, Municipio: Manzanillo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Manzanillo
# Solicitando datos para Indicador: 3104003001, Municipio: Minatitlán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Minatitlán
# Solicitando datos para Indicador: 3104003001, Municipio: Tecomán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tecomán
# Solicitando datos para Indicador: 3104003001, Municipio: Villa de Álvarez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Villa de Álvarez
# Solicitando datos para Indicador: 3104003001, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: No especificado
# Solicitando datos para Indicador: 3104003001, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros estados
# Solicitando datos para Indicador: 3104003001, Municipio: Otros municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Otros municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Resto de municipios
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Resto de municipios
# Solicitando datos para Indicador: 3104003001, Municipio: Chiapas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chiapas
# Solicitando datos para Indicador: 3104003001, Municipio: Acacoyagua
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Acacoyagua
# Solicitando datos para Indicador: 3104003001, Municipio: Acala
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Acala
# Solicitando datos para Indicador: 3104003001, Municipio: Acapetahua
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Acapetahua
# Solicitando datos para Indicador: 3104003001, Municipio: Altamirano
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Altamirano
# Solicitando datos para Indicador: 3104003001, Municipio: Amatán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Amatán
# Solicitando datos para Indicador: 3104003001, Municipio: Amatenango de la Frontera
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Amatenango de la Frontera
# Solicitando datos para Indicador: 3104003001, Municipio: Amatenango del Valle
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Amatenango del Valle
# Solicitando datos para Indicador: 3104003001, Municipio: Angel Albino Corzo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Angel Albino Corzo
# Solicitando datos para Indicador: 3104003001, Municipio: Arriaga
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Arriaga
# Solicitando datos para Indicador: 3104003001, Municipio: Bejucal de Ocampo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Bejucal de Ocampo
# Solicitando datos para Indicador: 3104003001, Municipio: Bella Vista
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Bella Vista
# Solicitando datos para Indicador: 3104003001, Municipio: Berriozábal
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Berriozábal
# Solicitando datos para Indicador: 3104003001, Municipio: Bochil
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Bochil
# Solicitando datos para Indicador: 3104003001, Municipio: El Bosque
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: El Bosque
# Solicitando datos para Indicador: 3104003001, Municipio: Cacahoatán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Cacahoatán
# Solicitando datos para Indicador: 3104003001, Municipio: Catazajá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Catazajá
# Solicitando datos para Indicador: 3104003001, Municipio: Cintalapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Cintalapa
# Solicitando datos para Indicador: 3104003001, Municipio: Coapilla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Coapilla
# Solicitando datos para Indicador: 3104003001, Municipio: Comitán de Domínguez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Comitán de Domínguez
# Solicitando datos para Indicador: 3104003001, Municipio: La Concordia
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Concordia
# Solicitando datos para Indicador: 3104003001, Municipio: Copainalá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Copainalá
# Solicitando datos para Indicador: 3104003001, Municipio: Chalchihuitán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chalchihuitán
# Solicitando datos para Indicador: 3104003001, Municipio: Chamula
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chamula
# Solicitando datos para Indicador: 3104003001, Municipio: Chanal
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chanal
# Solicitando datos para Indicador: 3104003001, Municipio: Chapultenango
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chapultenango
# Solicitando datos para Indicador: 3104003001, Municipio: Chenalhó
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chenalhó
# Solicitando datos para Indicador: 3104003001, Municipio: Chiapa de Corzo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chiapa de Corzo
# Solicitando datos para Indicador: 3104003001, Municipio: Chiapilla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chiapilla
# Solicitando datos para Indicador: 3104003001, Municipio: Chicoasén
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chicoasén
# Solicitando datos para Indicador: 3104003001, Municipio: Chicomuselo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chicomuselo
# Solicitando datos para Indicador: 3104003001, Municipio: Chilón
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Chilón
# Solicitando datos para Indicador: 3104003001, Municipio: Escuintla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Escuintla
# Solicitando datos para Indicador: 3104003001, Municipio: Francisco León
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Francisco León
# Solicitando datos para Indicador: 3104003001, Municipio: Frontera Comalapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Frontera Comalapa
# Solicitando datos para Indicador: 3104003001, Municipio: Frontera Hidalgo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Frontera Hidalgo
# Solicitando datos para Indicador: 3104003001, Municipio: La Grandeza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Grandeza
# Solicitando datos para Indicador: 3104003001, Municipio: Huehuetán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Huehuetán
# Solicitando datos para Indicador: 3104003001, Municipio: Huixtán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Huixtán
# Solicitando datos para Indicador: 3104003001, Municipio: Huitiupán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Huitiupán
# Solicitando datos para Indicador: 3104003001, Municipio: Huixtla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Huixtla
# Solicitando datos para Indicador: 3104003001, Municipio: La Independencia
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Independencia
# Solicitando datos para Indicador: 3104003001, Municipio: Ixhuatán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ixhuatán
# Solicitando datos para Indicador: 3104003001, Municipio: Ixtacomitán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ixtacomitán
# Solicitando datos para Indicador: 3104003001, Municipio: Ixtapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ixtapa
# Solicitando datos para Indicador: 3104003001, Municipio: Ixtapangajoya
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ixtapangajoya
# Solicitando datos para Indicador: 3104003001, Municipio: Jiquipilas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Jiquipilas
# Solicitando datos para Indicador: 3104003001, Municipio: Jitotol
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Jitotol
# Solicitando datos para Indicador: 3104003001, Municipio: Juárez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Juárez
# Solicitando datos para Indicador: 3104003001, Municipio: Larráinzar
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Larráinzar
# Solicitando datos para Indicador: 3104003001, Municipio: La Libertad
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Libertad
# Solicitando datos para Indicador: 3104003001, Municipio: Mapastepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mapastepec
# Solicitando datos para Indicador: 3104003001, Municipio: Las Margaritas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Las Margaritas
# Solicitando datos para Indicador: 3104003001, Municipio: Mazapa de Madero
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mazapa de Madero
# Solicitando datos para Indicador: 3104003001, Municipio: Mazatán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mazatán
# Solicitando datos para Indicador: 3104003001, Municipio: Metapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Metapa
# Solicitando datos para Indicador: 3104003001, Municipio: Mitontic
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Mitontic
# Solicitando datos para Indicador: 3104003001, Municipio: Motozintla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Motozintla
# Solicitando datos para Indicador: 3104003001, Municipio: Nicolás Ruíz
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Nicolás Ruíz
# Solicitando datos para Indicador: 3104003001, Municipio: Ocosingo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ocosingo
# Solicitando datos para Indicador: 3104003001, Municipio: Ocotepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ocotepec
# Solicitando datos para Indicador: 3104003001, Municipio: Ocozocoautla de Espinosa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ocozocoautla de Espinosa
# Solicitando datos para Indicador: 3104003001, Municipio: Ostuacán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Ostuacán
# Solicitando datos para Indicador: 3104003001, Municipio: Osumacinta
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Osumacinta
# Solicitando datos para Indicador: 3104003001, Municipio: Oxchuc
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Oxchuc
# Solicitando datos para Indicador: 3104003001, Municipio: Palenque
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Palenque
# Solicitando datos para Indicador: 3104003001, Municipio: Pantelhó
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pantelhó
# Solicitando datos para Indicador: 3104003001, Municipio: Pantepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pantepec
# Solicitando datos para Indicador: 3104003001, Municipio: Pichucalco
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pichucalco
# Solicitando datos para Indicador: 3104003001, Municipio: Pijijiapan
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pijijiapan
# Solicitando datos para Indicador: 3104003001, Municipio: El Porvenir
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: El Porvenir
# Solicitando datos para Indicador: 3104003001, Municipio: Villa Comaltitlán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Villa Comaltitlán
# Solicitando datos para Indicador: 3104003001, Municipio: Pueblo Nuevo Solistahuacán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Pueblo Nuevo Solistahuacán
# Solicitando datos para Indicador: 3104003001, Municipio: Rayón
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Rayón
# Solicitando datos para Indicador: 3104003001, Municipio: Reforma
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Reforma
# Solicitando datos para Indicador: 3104003001, Municipio: Las Rosas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Las Rosas
# Solicitando datos para Indicador: 3104003001, Municipio: Sabanilla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sabanilla
# Solicitando datos para Indicador: 3104003001, Municipio: Salto de Agua
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Salto de Agua
# Solicitando datos para Indicador: 3104003001, Municipio: San Cristóbal de las Casas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Cristóbal de las Casas
# Solicitando datos para Indicador: 3104003001, Municipio: San Fernando
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Fernando
# Solicitando datos para Indicador: 3104003001, Municipio: Siltepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Siltepec
# Solicitando datos para Indicador: 3104003001, Municipio: Simojovel
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Simojovel
# Solicitando datos para Indicador: 3104003001, Municipio: Sitalá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sitalá
# Solicitando datos para Indicador: 3104003001, Municipio: Socoltenango
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Socoltenango
# Solicitando datos para Indicador: 3104003001, Municipio: Solosuchiapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Solosuchiapa
# Solicitando datos para Indicador: 3104003001, Municipio: Soyaló
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Soyaló
# Solicitando datos para Indicador: 3104003001, Municipio: Suchiapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Suchiapa
# Solicitando datos para Indicador: 3104003001, Municipio: Suchiate
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Suchiate
# Solicitando datos para Indicador: 3104003001, Municipio: Sunuapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Sunuapa
# Solicitando datos para Indicador: 3104003001, Municipio: Tapachula
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tapachula
# Solicitando datos para Indicador: 3104003001, Municipio: Tapalapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tapalapa
# Solicitando datos para Indicador: 3104003001, Municipio: Tapilula
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tapilula
# Solicitando datos para Indicador: 3104003001, Municipio: Tecpatán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tecpatán
# Solicitando datos para Indicador: 3104003001, Municipio: Tenejapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tenejapa
# Solicitando datos para Indicador: 3104003001, Municipio: Teopisca
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Teopisca
# Solicitando datos para Indicador: 3104003001, Municipio: Tila
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tila
# Solicitando datos para Indicador: 3104003001, Municipio: Tonalá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tonalá
# Solicitando datos para Indicador: 3104003001, Municipio: Totolapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Totolapa
# Solicitando datos para Indicador: 3104003001, Municipio: La Trinitaria
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: La Trinitaria
# Solicitando datos para Indicador: 3104003001, Municipio: Tumbalá
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tumbalá
# Solicitando datos para Indicador: 3104003001, Municipio: Tuxtla Gutiérrez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tuxtla Gutiérrez
# Solicitando datos para Indicador: 3104003001, Municipio: Tuxtla Chico
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tuxtla Chico
# Solicitando datos para Indicador: 3104003001, Municipio: Tuzantán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tuzantán
# Solicitando datos para Indicador: 3104003001, Municipio: Tzimol
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Tzimol
# Solicitando datos para Indicador: 3104003001, Municipio: Unión Juárez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Unión Juárez
# Solicitando datos para Indicador: 3104003001, Municipio: Venustiano Carranza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Venustiano Carranza
# Solicitando datos para Indicador: 3104003001, Municipio: Villa Corzo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Villa Corzo
# Solicitando datos para Indicador: 3104003001, Municipio: Villaflores
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Villaflores
# Solicitando datos para Indicador: 3104003001, Municipio: Yajalón
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Yajalón
# Solicitando datos para Indicador: 3104003001, Municipio: San Lucas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Lucas
# Solicitando datos para Indicador: 3104003001, Municipio: Zinacantán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Zinacantán
# Solicitando datos para Indicador: 3104003001, Municipio: San Juan Cancuc
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: San Juan Cancuc
# Solicitando datos para Indicador: 3104003001, Municipio: Aldama
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Aldama
# Solicitando datos para Indicador: 3104003001, Municipio: Benemérito de las Américas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Benemérito de las Américas
# Solicitando datos para Indicador: 3104003001, Municipio: Maravilla Tenejapa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Maravilla Tenejapa
# Solicitando datos para Indicador: 3104003001, Municipio: Marqués de Comillas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 3104003001, Municipio: Marqués de Comillas
# Solicitando datos para Indicador: 3104003001, Municipio: Montecristo de Guerrero
# ...
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Santa María del Oro
# Solicitando datos para Indicador: 6207129646, Municipio: Santiago Ixcuintla
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Santiago Ixcuintla
# Solicitando datos para Indicador: 6207129646, Municipio: Tecuala
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Tecuala
# Solicitando datos para Indicador: 6207129646, Municipio: Tepic
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Tepic
# Solicitando datos para Indicador: 6207129646, Municipio: Tuxpan
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Tuxpan
# Solicitando datos para Indicador: 6207129646, Municipio: La Yesca
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: La Yesca
# Solicitando datos para Indicador: 6207129646, Municipio: Bahía de Banderas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Bahía de Banderas
# Solicitando datos para Indicador: 6207129646, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: No especificado
# Solicitando datos para Indicador: 6207129646, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Otros estados
# Solicitando datos para Indicador: 6207129646, Municipio: Nuevo León
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Nuevo León
# Solicitando datos para Indicador: 6207129646, Municipio: Abasolo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Abasolo
# Solicitando datos para Indicador: 6207129646, Municipio: Agualeguas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Agualeguas
# Solicitando datos para Indicador: 6207129646, Municipio: Los Aldamas
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Los Aldamas
# Solicitando datos para Indicador: 6207129646, Municipio: Allende
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Allende
# Solicitando datos para Indicador: 6207129646, Municipio: Anáhuac
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Anáhuac
# Solicitando datos para Indicador: 6207129646, Municipio: Apodaca
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Apodaca
# Solicitando datos para Indicador: 6207129646, Municipio: Aramberri
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Aramberri
# Solicitando datos para Indicador: 6207129646, Municipio: Bustamante
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Bustamante
# Solicitando datos para Indicador: 6207129646, Municipio: Cadereyta Jiménez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Cadereyta Jiménez
# Solicitando datos para Indicador: 6207129646, Municipio: El Carmen
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: El Carmen
# Solicitando datos para Indicador: 6207129646, Municipio: Cerralvo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Cerralvo
# Solicitando datos para Indicador: 6207129646, Municipio: Ciénega de Flores
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Ciénega de Flores
# Solicitando datos para Indicador: 6207129646, Municipio: China
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: China
# Solicitando datos para Indicador: 6207129646, Municipio: Doctor Arroyo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Doctor Arroyo
# Solicitando datos para Indicador: 6207129646, Municipio: Doctor Coss
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Doctor Coss
# Solicitando datos para Indicador: 6207129646, Municipio: Doctor González
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Doctor González
# Solicitando datos para Indicador: 6207129646, Municipio: Galeana
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Galeana
# Solicitando datos para Indicador: 6207129646, Municipio: García
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: García
# Solicitando datos para Indicador: 6207129646, Municipio: San Pedro Garza García
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: San Pedro Garza García
# Solicitando datos para Indicador: 6207129646, Municipio: General Bravo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Bravo
# Solicitando datos para Indicador: 6207129646, Municipio: General Escobedo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Escobedo
# Solicitando datos para Indicador: 6207129646, Municipio: General Terán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Terán
# Solicitando datos para Indicador: 6207129646, Municipio: General Treviño
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Treviño
# Solicitando datos para Indicador: 6207129646, Municipio: General Zaragoza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Zaragoza
# Solicitando datos para Indicador: 6207129646, Municipio: General Zuazua
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: General Zuazua
# Solicitando datos para Indicador: 6207129646, Municipio: Guadalupe
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Guadalupe
# Solicitando datos para Indicador: 6207129646, Municipio: Los Herreras
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Los Herreras
# Solicitando datos para Indicador: 6207129646, Municipio: Higueras
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Higueras
# Solicitando datos para Indicador: 6207129646, Municipio: Hualahuises
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Hualahuises
# Solicitando datos para Indicador: 6207129646, Municipio: Iturbide
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Iturbide
# Solicitando datos para Indicador: 6207129646, Municipio: Juárez
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Juárez
# Solicitando datos para Indicador: 6207129646, Municipio: Lampazos de Naranjo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Lampazos de Naranjo
# Solicitando datos para Indicador: 6207129646, Municipio: Linares
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Linares
# Solicitando datos para Indicador: 6207129646, Municipio: Marín
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Marín
# Solicitando datos para Indicador: 6207129646, Municipio: Melchor Ocampo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Melchor Ocampo
# Solicitando datos para Indicador: 6207129646, Municipio: Mier y Noriega
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Mier y Noriega
# Solicitando datos para Indicador: 6207129646, Municipio: Mina
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Mina
# Solicitando datos para Indicador: 6207129646, Municipio: Montemorelos
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Montemorelos
# Solicitando datos para Indicador: 6207129646, Municipio: Monterrey
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Monterrey
# Solicitando datos para Indicador: 6207129646, Municipio: Parás
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Parás
# Solicitando datos para Indicador: 6207129646, Municipio: Pesquería
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Pesquería
# Solicitando datos para Indicador: 6207129646, Municipio: Los Ramones
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Los Ramones
# Solicitando datos para Indicador: 6207129646, Municipio: Rayones
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Rayones
# Solicitando datos para Indicador: 6207129646, Municipio: Sabinas Hidalgo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Sabinas Hidalgo
# Solicitando datos para Indicador: 6207129646, Municipio: Salinas Victoria
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Salinas Victoria
# Solicitando datos para Indicador: 6207129646, Municipio: San Nicolás de los Garza
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: San Nicolás de los Garza
# Solicitando datos para Indicador: 6207129646, Municipio: Hidalgo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Hidalgo
# Solicitando datos para Indicador: 6207129646, Municipio: Santa Catarina
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Santa Catarina
# Solicitando datos para Indicador: 6207129646, Municipio: Santiago
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Santiago
# Solicitando datos para Indicador: 6207129646, Municipio: Vallecillo
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Vallecillo
# Solicitando datos para Indicador: 6207129646, Municipio: Villaldama
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Villaldama
# Solicitando datos para Indicador: 6207129646, Municipio: 902	Municipios de Monterrey, Apodaca, San Pedro Garza García, General Escobedo, Guadalupe, Juárez, San Nicolás de los Garza, Santa Catarina y García
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: 902	Municipios de Monterrey, Apodaca, San Pedro Garza García, General Escobedo, Guadalupe, Juárez, San Nicolás de los Garza, Santa Catarina y García
# Solicitando datos para Indicador: 6207129646, Municipio: No especificado
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: No especificado
# Solicitando datos para Indicador: 6207129646, Municipio: Otros estados
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Otros estados
# Solicitando datos para Indicador: 6207129646, Municipio: Oaxaca
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Oaxaca
# Solicitando datos para Indicador: 6207129646, Municipio: Abejones
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Abejones
# Solicitando datos para Indicador: 6207129646, Municipio: Acatlán de Pérez Figueroa
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Acatlán de Pérez Figueroa
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Cacalotepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Cacalotepec
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Cuyotepeji
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Cuyotepeji
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Ixtaltepec
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Ixtaltepec
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Nochixtlán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Nochixtlán
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Ocotlán
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Ocotlán
# Solicitando datos para Indicador: 6207129646, Municipio: Asunción Tlacolulita
# Respuesta recibida. Código de estado: 200
# La respuesta no contiene una lista en la clave 'Series'. Indicador: 6207129646, Municipio: Asunción Tlacolulita
# Solicitando datos para Indicador: 6207129646, Municipio: Ayotzintepec

# %% [markdown]
# # Descargar el listado de municipios desde la API
# Funcional!

# %%
import requests
import pandas as pd

# Tu API key
api_key = "d312de10-427b-d618-3b58-f77e37afd922"

# URL de la API para obtener los códigos de todos los municipios
url = f"https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/CL_GEO_AREA/null/es/BISE/2.0/{api_key}?type=json"

# Realizar la solicitud HTTP para obtener los códigos de municipios
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    try:
        data = response.json()
        
        # Crear una lista de códigos de municipios y sus nombres
        municipios = []
        for item in data["CODE"]:
            municipio = {
                "CodigoMunicipio": item["value"],
                "NombreMunicipio": item["Description"]
            }
            municipios.append(municipio)

        # Crear un DataFrame con los datos de los municipios
        municipios_df = pd.DataFrame(municipios)

        # Guardar los datos en un archivo CSV
        csv_filename = "municipios.csv"
        municipios_df.to_csv(csv_filename, index=False)

        print("Códigos de municipios guardados exitosamente en", csv_filename)
    except ValueError as e:
        print("Error al decodificar JSON:", e)
else:
    print("Error en la solicitud HTTP. Código de estado:", response.status_code)
# Out:
# Códigos de municipios guardados exitosamente en municipios.csv

# %% [markdown]
# # Variables de migración selección:
#
# https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/6200205262,6200205277,6200240404,6200240501,6207129646/es/0700/true/BISE/2.0/[Aquí va tu Token]?type=json
#
# usados = 3104003001", "6200205262", "6200240404", "6200240501", "6207129646
#
# nuevos = 6200205262, 6200205277, 6200240404,6200240501,6207129646
#
#
# falta = 6200205277
